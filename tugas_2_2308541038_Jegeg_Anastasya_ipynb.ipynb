# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Formatted String**

# %%
waktu = input ("Jesya: Sekarang pagi, siang, atau malam? You:")
format_waktu = f"Jesya: WAAAA Selamat {waktu}  yaa!!! "
print (format_waktu)
print ("Jesya: Ngomong ngomong kenalin, namaku Jesya HEHEHE")
nama = input ("Jesya: Kalau boleh tahu nama mu siapa? You:")
format_nama = f"Jesya: HAIII  {nama} selamat datang di ruang curhat ya!!!"
print (format_nama)
print ("Jesya: Kamu bisa cerita apapun disini, jadi jangan ada rahasia diantara kita ya")
print ("Jesya: Ceritamu bakalan aman di aku jadii, AYOO!!!")
siap = input("Jesya: Kalaau begituuuu, apa kamu sudah siap? You:")
format_siap = f"Jesya: OKAYYY SIAP NGGA SIAP, Harus siapp yaa wkwkkwwk"
print (format_siap)
kabar = input ("Jesya: Oiyaa bagaimana keadaanmu sekarang? You:")
format_kabar = f"Jesya: Oalahhh begitu,kalau kamu disuruh untuk ngulang persaan atau kegiatan tadi kamu mau ngga?"
print (format_kabar)
print("Jesya: Waww iiyaaa????")
yes_no = input ("You:")
cerita = input ("Jesya: Kalau kamu mau cerita lagi tentang keseharian muu bolehh bangett... Tinggal ketik ajaa yaa You:")
format_cerita = f"Jesya: Wahhh makasiii banyakk kalau kamu udahh mau ceritaa ,<3 SEMANGAT!!!!!"
print (format_cerita)
# Out:
# Jesya: Sekarang pagi, siang, atau malam? You: malam
# Jesya: WAAAA Selamat malam  yaa!!!
# Jesya: Ngomong ngomong kenalin, namaku Jesya HEHEHE
# Jesya: Kalau boleh tahu nama mu siapa? You: minie
# Jesya: HAIII  minie selamat datang di ruang curhat ya!!!
# Jesya: Kamu bisa cerita apapun disini, jadi jangan ada rahasia diantara kita ya
# Jesya: Ceritamu bakalan aman di aku jadii, AYOO!!!
# Jesya: Kalaau begituuuu, apa kamu sudah siap? You: siap
# Jesya: OKAYYY SIAP NGGA SIAP, Harus siapp yaa wkwkkwwk
# Jesya: Oiyaa bagaimana keadaanmu sekarang? You: baik
# Jesya: Oalahhh begitu,kalau kamu disuruh untuk ngulang persaan atau kegiatan tadi kamu mau ngga?
# Jesya: Waww iiyaaa????
# You: iyaa
# Jesya: Kalau kamu mau cerita lagi tentang keseharian muu bolehh bangett... Tinggal ketik ajaa yaa You: wokeyyy
# Jesya: Wahhh makasiii banyakk kalau kamu udahh mau ceritaa ,<3 SEMANGAT!!!!!

# %% [markdown]
# Operasi matematika

# %%
angka_7 = input ("Masukkan bilangan bebas 1")
angka_8 = input ("Masukkan bilangan bebas 2")
format_angka4 = int(angka_7) + int(angka_8)
print ("Hasil pertambahannya adalah:", format_angka4)
print ("Senang bukan?, okeyy ayo lanjut ke, KEPO YAAAAA")
angka_1 = input ("Masukkan bilangan bulat")
angka_2 = input ("Masukkan bilangan bulat")
format_angka = int(angka_1) * int(angka_2)
print ("Hasilnya perkalianya adalah:", format_angka)
print ("Widiww perkalian udah, pertambahan udahh, lanjut lagi niiii")
angka_5 = input ("Masukkan bilangan bebas")
angka_6 = input ("Masukkan bilangan bebas")
format_angka3 = int(angka_5) - int(angka_6)
print ("Hasil pengurangannya adalah:", format_angka3)
print ("Gimanaa gampang gampang bukannnn, move lagiiii")
angka_3 = input ("Masukkan bilangan bulat")
angka_4 = input ("Masukkan bilangan bulat lain")
format_angka2 = int(angka_3) // int(angka_4)
print ("Hasil pembagian yang telah dibulatkan adalah:", format_angka2)
print ("Wadaww ngga bisa ke desimal nihh, hayoooo")
angka_9 = input ("Masukkan bilangan yang akan menjadi X")
angka_10 = input ("Masukkan bilangan yang akan mejadi Y")
format_angka5 = int(angka_9) + int(angka_10) / int (angka_9)
print ("Hasilnya adalah:", format_angka5)
print ("Ayoo tebak ko bisa kaya gituuu",)
print ("Main perbandingan angka yokk")
print ("Aku mulai yaa")
angka_11 = input ("Masukkin bilangan berapapun (1)")
angka_12 = input ("Masukin bilangan berapapun (2)")
format_angka6 = str(angka_11) > str(angka_12)
print (format_angka6, "Bener ngga? enter dulu yaa")
salber1 = input()
print ("Heheheh makasii udah coba main yaaa")
format_angka7 = int(angka_11) < int(angka_12)
print (format_angka7, "Bener ngga? enter dulu yaa")
salber2 = input() (str("Kalau bener enter sekali, kalau salah enter dua kali"))
print ("Heheheh makasii udah coba main yaaa")
print ("Yahhhh salah lagi yaaa, yaudah aku coba lagi ya")
format_angka8 = (angka_11) == (angka_12)
print (format_angka8)
print ("WAWWWW AKHIRNYAAAAAAA")
print ("BYEBYEEEE")

# %% [markdown]
# String index

# %%
nama_1 = input ("Masukkan namamu")
print ("Hai", nama_1[0:])
nama = "Ni Kadek Jegeg Anastasya Dwipayanti"
print ("Halllooo salam kenal",)
print ("Hai haiii namakuuuu",nama[8:-10])
print ("BTW kalo disingkat jadi Jesya ngehhehee")
print ("Namamu jumlah huruf nya sama spasi", (len(nama_1)), "yaaa")
print ("Betul ngga? hitung baik baik ya")
nama_1.upper()
print ("Ini namamu kalo pake kapital")
