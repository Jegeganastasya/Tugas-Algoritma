# %%
import numpy as np
import matplotlib.pyplot as plt

kasus_38 = float(input("Kasus berapakah yang akan dikerjakan? "))

if kasus_38==1:
    print("Masing-masing garis akan melewati dua titik yang diketahui.")
    a_38 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
    b_38 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
    c_38 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
    d_38 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

    e_38 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
    f_38 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
    g_38 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
    h_38 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

    m_1_38 = (d_38-b_38)/(c_38-a_38) # Gradien garis pertama
    m_2_38 = (h_38-f_38)/(g_38-e_38) # Gradien garis kedua

    # Persamaan garis pertama adalah y=m_1(x-a)+b=m_1x-m_1a+b
    # Persamaan garis kedua adalah y=m_2(x-e)+f=m_2x-m_2e+f

    c_1_38 = -m_1_38*a_38+b_38 # Titik potong garis pertama terhadap sumbu y
    c_2_38 = -m_2_38*e_38+f_38 # titik potong garis kedua terhadap sumbu y garis kedua

    print("Persamaan garis pertama adalah y={:.3f}x+{:.3f}".format(m_1_38,c_1_38))
    print("Persamaan garis kedua adalah y={:.3f}x+{:.3f}".format(m_2_38,c_2_38))

    if m_1_38==m_2_38:
        #print("Kedua garis sejajar sehingga kemungkinannya adalah tidak terdapat solusi atau terdapat tak berhingga banyaknya solusi")
        if c_1_38 == c_2_38:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
            x=np.linspace(-5,5,100)
            plt.plot(x,m_1_38*(x-a_38)+b_38,color='red')
            plt.plot(x,m_2_38_38*(x-e_38)+f_38,color='blue')
            plt.axvline(x=0,color='grey')
            plt.axhline(y=0,color='grey')
            plt.show()
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")
            x=np.linspace(-5,5,100)
            plt.plot(x,m_1_38*(x-a_38)+b_38,color='red')
            plt.plot(x,m_2_38*(x-e_38)+f_38,color='blue')
            plt.axvline(x=0,color='grey')
            plt.axhline(y=0,color='grey')
            plt.show()
    else:
        print("Akan terdapat satu titik potong")
        tp_x_38 = (-m_2_38*e_38+f_38+m_1_38*a_38-b_38)/(m_1_38-m_2_38)
        tp_y_38 = m_1_38*(tp_x_38-a_38)+b_38
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_38,tp_y_38))
    
        x=np.linspace(tp_x_38-5,tp_x_38+5,100)
        plt.plot(x,m_1_38*(x-a_38)+b_38,color='red',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m_1_38,a_38,b_38))
        plt.plot(x,m_2_38*(x-e_38)+f_38,color='blue',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m_2_38,e_38,f_38))
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.legend(loc='best')
        plt.show()
        
elif kasus_38==2:
    print("Masing-masing garis diketahui gradien dan titik yang dilewati.")
    m_1_38 = float(input("Gradien dari garis pertama adalah "))
    a_38 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah "))
    b_38 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah "))
    
    print("Persamaan garis pertama adalah y={}(x-{})+{}".format(m_1_38,a_38,b_38))
    
    m_2_38 = float(input("Gradien dari garis kedua adalah "))
    c_38 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah "))
    d_38 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah "))
    print("Persamaan garis kedua adalah y={}(x-{})+{}".format(m_2_38,c_38,d_38))
    
    c_1_38 = -m_1_38*a_38+b_38
    c_2_38 = -m_2_38*c_38+d_38
    
    if m_1_38==m_2_38:
        print("Kedua garis sejajar")
        
        if c_1_38 == c_2_38:
            print("Terdapat tak berhingga banyaknya solusi")
            x=np.linspace(-5,5,100)
            plt.plot(x,m_1_38*(x-a_38)+b_38,color='red')
            plt.plot(x,m_2_38*(x-c_38_38)+d_38,color='blue')
            plt.axvline(x=0,color='grey')
            plt.axhline(y=0,color='grey')
            plt.show()
        else:
            print("Tidak terdapat solusi")
            x=np.linspace(-5,5,100)
            plt.plot(x,m_1_38*(x-a_38)+b_38,color='red')
            plt.plot(x,m_2_38*(x-c_38)+d_38,color='blue')
            plt.axvline(x=0,color='grey')
            plt.axhline(y=0,color='grey')
            plt.show()
    else:
        print("Kedua garis akan berpotongan di satu titik.")
        tp_x_38= (-m_2_38*c_38+d_38+m_1_38*a_38-b_38)/(m_1_38-m_2_38)
        tp_y_38 = m_1_38*(tp_x_38-a_38)+b_38
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_38,tp_y_38))
        x=np.linspace(tp_x_38-5,tp_x_38+5,100)
        plt.plot(x,m_1_38*(x-a_38)+b_38,color='red',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m_1_38,a_38,b_38))
        plt.plot(x,m_2_38*(x-c_38)+d_38,color='blue',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m_2_38,c_38,d_38))
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.legend(loc='best')
        plt.show()
elif kasus_38==3:
    print("Kedua garis memenuhi persamaan berbentuk ax+by=c dan dx+ey=f.")
    a_38=float(input("Koefisien dari x pada garis pertama adalah "))
    b_38=float(input("Koefisien dari y pada garis pertama adalah "))
    c_38=float(input("Konstanta dari garis pertama adalah "))
    
    d_38=float(input("Koefisien dari x pada garis kedua adalah "))
    e_38=float(input("Koefisien dari y pada garis kedua adalah "))
    f_38=float(input("Konstanta dari garis kedua adalah "))
    
    m_1_38 = (-a)/b
    m_2_38 = (-d)/e
    
    c_1_38=c/b
    c_2_38=f/e
    
    kb_38 = c_38/b_38
    kf_38 = e_38/f_38
    
    if m_1_38==m_2_38:
        print("Kedua garis akan sejajar")
        
        if c_1_38==c_2_38:
            print("Kedua garis berhimpitan")
            x=np.linspace(-5,5,100)
            plt.plot(x,m_1_38*x+c_38/b_38,color='red')
            plt.plot(x,m_2_38*x+f_38/e_38,color='blue')
            plt.axvline(x=0,color='grey')
            plt.axhline(y=0,color='grey')
            plt.show()
        else:
            print("Kedua garis sejajar")
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")
            x=np.linspace(-5,5,100)
            plt.plot(x,m_1_38*x_38+c_38/b_38,color='red')
            plt.plot(x,m_2_38*x_38+f_38/e_38,color='blue')
            plt.axvline(x=0,color='grey')
            plt.axhline(y=0,color='grey')
            plt.show()
            
    else:
        print("kedua garis akan berpotongan di satu titik")
        tp_x_38 = (f_38-(e_38*c_38)/b_38)/(d_38-(e_38*a_38)/b_38)
        tp_y_38 = (-a_38*tp_x_38)/b_38 + c_38/b_38
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_38,tp_y_38))
        x=np.linspace(tp_x_38-5,tp_x_38+5,100)
        plt.plot(x,m_1_38*x+c_38/b_38,color='red',label="y={:.3f}x+{:.3f}".format(m_2_38,kb_38))
        plt.plot(x,m_2_38*x+f_38/e_38,color='blue',label="y={:.3f}x+{:.3f}".format(m_1_38,kf_38))
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.legend(loc='best')
        plt.show()
else:
    print("Hanya terdapat 3 kasus. Mohon masukkan 1, 2 atau 3 saja.")

# %%
# Persamaan garis yang melewati 2 titik
# Garis pertama melewati (a,b) dan (c,d)
# Garis kedua melewati (e,f) dan (g,h)
# Terdapat 3 kemungkinan dari kedua persamaan garis ini:
# 1. Terdapat perpotongan di satu titik (gradien kedua garis tidak sama)
# 2. Terdapat tak berhingga banyaknya solusi (kedua garis berhimpitan) (kedua garis sejajar)
# 3. Tidak terdapat perpotongan garis (tidak terdapat solusi) (kedua garis sejajar)

import numpy as np
import matplotlib.pyplot as plt

a_38 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
b_38 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
c_38 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
d_38 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

e_38 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
f_38 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
g_38 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
h_38 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

m_1_38 = (d_38-b_38)/(c_38-a_38) # Gradien garis pertama
m_2_38 = (h_38-f_38)/(g_38-e_38) # Gradien garis kedua

# Persamaan garis pertama adalah y=m_1(x-a)+b=m_1x-m_1a+b
# Persamaan garis kedua adalah y=m_2(x-e)+f=m_2x-m_2e+f

c_1_38 = -m_1_38*a_38+b_38 # Titik potong garis pertama terhadap sumbu y
c_2_38 = -m_2_38*e_38+f_38 # titik potong garis kedua terhadap sumbu y garis kedua

print("Persamaan garis pertama adalah y={}x+{}".format(m_1_38,c_1_38))
print("Persamaan garis kedua adalah y={}x+{}".format(m_2_38,c_2_38))

if m_1_38==m_2_38:
    #print("Kedua garis sejajar sehingga kemungkinannya adalah tidak terdapat solusi atau terdapat tak berhingga banyaknya solusi")
    if c_1_38 == c_2_38:
        print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_38*(x-a_38)+b_38,color='red')
        plt.plot(x,m_2_38*(x-e_38)+f_38,color='blue')
        plt.show()
    else:
        print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_38*(x-a_38)+b_38,color='red')
        plt.plot(x,m_2_38*(x-e_38)+f_38,color='blue')
        plt.show()
else:
    print("Akan terdapat satu titik potong")
    tp_x_38 = (-m_2_38*e_38+f_38+m_1_38*a_38-b_38)/(m_1_38-m_2_38)
    tp_y_38 = m_1_38*(tp_x_38-a_38)+b_38
    print("Titik potong kedua garis adalah ({},{})".format(tp_x_38,tp_y_38))
    
    x=np.linspace(tp_x_38-5,tp_x_38+5,100)
    plt.plot(x,m_1_38*(x-a_38)+b_38,color='red')
    plt.plot(x,m_2_38*(x-e_38)+f_38,color='blue')
    plt.axvline(x=0,color='grey')
    plt.axhline(y=0,color='grey')
    plt.show()

# %%
import numpy as np
a=1
b=1
d=3
e=2

c = 2
f = 3
if a*e-b*d!=0:
    A=np.array([[a,b],[d,e]])
    C=np.array([[c],[f]])
    Ainv = np.linalg.inv(A)
    print(Ainv)
    tp_xy = np.matmul(Ainv,C)
    print(tp_xy)
else:
    print("Matrix singular")
