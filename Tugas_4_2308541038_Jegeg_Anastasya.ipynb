# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
a = [' 1 = Do ',' 2 = Re ',' 3 = Mi ',' 4 = Fa ',' 5 = Sol ',' 6 = La ',' 7 = Si ']
for doremi in a:
    print("Notasi", doremi,"Lebih Kecil Dari Do 8")
    
print(len(a))
print("do" in a)
print(' 1 = Do ' in a)
# Out:
# Notasi  1 = Do  Lebih Kecil Dari Do 8
# Notasi  2 = Re  Lebih Kecil Dari Do 8
# Notasi  3 = Mi  Lebih Kecil Dari Do 8
# Notasi  4 = Fa  Lebih Kecil Dari Do 8
# Notasi  5 = Sol  Lebih Kecil Dari Do 8
# Notasi  6 = La  Lebih Kecil Dari Do 8
# Notasi  7 = Si  Lebih Kecil Dari Do 8
# 7
# False
# True

# %%
print("Mari membandingkan bilangan")
print("Masukan bilangan acak hanya satu karakter contoh: 1")
a_1 = input("Masukan")
a_2 = input("Masukan lagi")
a_3 = input("Masukan lagi")
a_4 = input("Masukan lagi")
a_5 = input("Masukkan lagi")
b = input("Masukan satu bilangan pembanding")

if a_1 < b:
    list_a =  a_1 
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih kecil dari", b)
elif a_1 > b:
    list_a = a_1
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih besar dari", b)
        

if a_2 < b:
    list_a =  a_2 
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih kecil dari", b)
elif a_2 > b:
    list_a = a_2
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih besar dari", b)
        

if a_3 < b:
    list_a =  a_3 
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih kecil dari", b)
elif a_3 > b:
    list_a = a_3
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih besar dari", b)


if a_4 < b:
    list_a =  a_4 
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih kecil dari", b)
elif a_4 > b:
    list_a = a_4
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih besar dari", b)
        
if a_5 < b:
    list_a =  a_5 
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih kecil dari", b)
elif a_5 > b:
    list_a = a_5
    for doremi in list_a:
        print("Bilangan ", doremi, "lebih besar dari", b)
# Out:
# Mari membandingkan bilangan
# Masukan bilangan acak hanya satu karakter contoh: 1
# Masukan 4
# Masukan lagi 7
# Masukan lagi 9
# Masukan lagi 2
# Masukkan lagi 1
# Masukan satu bilangan pembanding 5
# Bilangan  4 lebih kecil dari 5
# Bilangan  7 lebih besar dari 5
# Bilangan  9 lebih besar dari 5
# Bilangan  2 lebih kecil dari 5
# Bilangan  1 lebih kecil dari 5
