# %%
import numpy as np
import math
import cmath

#masukkan akar akar dari persamaan yang telah ditentukan
x1_38 = (-1 - math.sqrt(5**0.5))/ 2
x2_38 = (-1 + math.sqrt(5**0.5))/ 2
print(x2_38)
#mencari nilai n dari persamaan tersebut
#karena (1-x) = x**2 maka ubah setiap bentuk (1-x) menjadi x**2

xmas = float(input("Masukkan bilangan antara -1.2476743906106103 atau 0.6180339887498948 "))

#karena (1-x) dapat diubah maka bentuk penguadratannya akan menjadi x**2026 dan x**3 dengan sifat logaritma log a**b = b log a
if xmas == 0.6180339887498948:
    n1_38 = (2026 * math.log(abs(x2_38))) /( 3 * math.log(abs(x2_38)))
    print(n1_38)
elif xmas == -1.2476743906106103:
    n2_38 = (2026 * math.log(abs(x1_38))) /( 3 * math.log(abs(x1_38)))
    print(n2_38)
else:
    print("Masukkan bilangan yang diminta")
